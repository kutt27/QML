# %% [markdown]
# ### ZZFeatureMap

# %%
from qiskit.circuit.library import ZZFeatureMap
qc_zz = ZZFeatureMap(3, reps=1, insert_barriers=True)
qc_zz.decompose().draw()

# %% [raw]
# Repetition works by running the circuit multiple times and averaging the results. This helps to reduce the impact of noise, which can cause errors in the output of the circuit.
#
# Barriers work by preventing errors from propagating. When a barrier is inserted between two gates, it ensures that the output of the first gate is not affected by the input of the second gate. This helps to prevent errors from accumulating in the output of the circuit.

# %% [markdown]
# ### TwoLocal Circuit

# %%
from qiskit.circuit.library import TwoLocal
qc_twolocal = TwoLocal(num_qubits=3, reps=2, rotation_blocks=['ry','rz'],
                entanglement_blocks='cz', skip_final_rotation_layer=True,
                insert_barriers=True)

qc_twolocal.decompose().draw()
